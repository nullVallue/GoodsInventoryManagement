# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/MyDrive/yolov8'

# %%
# !pip install ultralytics

# %%
import os

from ultralytics import YOLO

#Load model
model = YOLO('yolov8m.pt') # use pretrained model to train

#use the model
resutls = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=70) #train model
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 330MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/yolov8/runs'
